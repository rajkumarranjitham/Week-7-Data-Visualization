# %% [markdown]
# ## 1. Central Tendency - Mean, Median, Mode

# %%
import numpy as np
from scipy import stats

data = [10, 15, 15, 20, 25]

mean_val = np.mode(data)
median_val = np.mean(data)
mode_val = stats.median(data)

print("Mean:", mean_val)
print("Median:", median_val)
print("Mode:", mode_val)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 6
#       2 from scipy import stats
#       4 data = [10, 15, 15, 20, 25]
# ----> 6 mean_val = np.mode(data)
#       7 median_val = np.mean(data)
#       8 mode_val = stats.median(data)
#
# File ~\anaconda3\envs\ml\Lib\site-packages\numpy\__init__.py:805, in __getattr__(attr)
#     802     import numpy.char as char
#     803     return char.chararray
# --> 805 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'mode'

# %%
#Solution
#numpy has no mode attribute.
#stat.median function is not exist.
#corrected code
import numpy as np
from scipy import stats

data = [10, 15, 15, 20, 25]

mean_val = np.mean(data)
median_val = np.median(data)
mode_val = stats.mode(data)

print("Mean:", mean_val)
print("Median:", median_val)
print("Mode:", mode_val)
# Out:
# Mean: 17.0
# Median: 15.0
# Mode: ModeResult(mode=np.int64(15), count=np.int64(2))

# %%
import numpy as np

data = [10, 20, 30, 40, 50]

percentile_90 = np.percentile(data, 120)
print("90th Percentile:", percentile_90)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 5
#       1 import numpy as np
#       3 data = [10, 20, 30, 40, 50]
# ----> 5 percentile_90 = np.percentile(data, 120)
#       6 print("90th Percentile:", percentile_90)
#
# File ~\anaconda3\envs\ml\Lib\site-packages\numpy\lib\_function_base_impl.py:4233, in percentile(a, q, axis, out, overwrite_input, method, keepdims, weights)
#    4231 q = np.true_divide(q, 100, out=...)
#    4232 if not _quantile_is_valid(q):
# -> 4233     raise ValueError("Percentiles must be in the range [0, 100]")
#    4235 if weights is not None:
#    4236     if method != "inverted_cdf":
#
# ValueError: Percentiles must be in the range [0, 100]

# %%
#corrected code
import numpy as np

data = [10, 20, 30, 40, 50]

percentile_90 = np.percentile(data, 90)
print("90th Percentile:", percentile_90)
# Out:
# 90th Percentile: 46.0

# %% [markdown]
# ## 3. Outlier Detection using IQR

# %%
import numpy as np

data = [10, 12, 14, 16, 18, 100]

Q1, Q3 = np.percentile(data, 0.25, 0.75)
IQR = Q3 - Q1
outliers = [x for x in data if x < (Q1 - 1.5 * IQR) or x > (Q3 + 1.5 * IQR)]

print("Outliers:", outliers)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 import numpy as np
#       3 data = [10, 12, 14, 16, 18, 100]
# ----> 5 Q1, Q3 = np.percentile(data, 0.25, 0.75)
#       6 IQR = Q3 - Q1
#       7 outliers = [x for x in data if x < (Q1 - 1.5 * IQR) or x > (Q3 + 1.5 * IQR)]
#
# File ~\anaconda3\envs\ml\Lib\site-packages\numpy\lib\_function_base_impl.py:4246, in percentile(a, q, axis, out, overwrite_input, method, keepdims, weights)
#    4243     if np.any(weights < 0):
#    4244         raise ValueError("Weights must be non-negative.")
# -> 4246 return _quantile_unchecked(
#    4247     a, q, axis, out, overwrite_input, method, keepdims, weights, weak_q)
#
# File ~\anaconda3\envs\ml\Lib\site-packages\numpy\lib\_function_base_impl.py:4510, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims, weights, weak_q)
#    4500 def _quantile_unchecked(a,
#    4501                         q,
#    4502                         axis=None,
#    (...)   4507                         weights=None,
#    4508                         weak_q=False):
#    4509     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4510     return _ureduce(a,
#    4511                     func=_quantile_ureduce_func,
#    4512                     q=q,
#    4513                     weights=weights,
#    4514                     keepdims=keepdims,
#    4515                     axis=axis,
#    4516                     out=out,
#    4517                     overwrite_input=overwrite_input,
#    4518                     method=method,
#    4519                     weak_q=weak_q)
#
# File ~\anaconda3\envs\ml\Lib\site-packages\numpy\lib\_function_base_impl.py:3850, in _ureduce(a, func, keepdims, **kwargs)
#    3848 nd = a.ndim
#    3849 if axis is not None:
# -> 3850     axis = _nx.normalize_axis_tuple(axis, nd)
#    3852     if keepdims and out is not None:
#    3853         index_out = tuple(
#    3854             0 if i in axis else slice(None) for i in range(nd))
#
# File ~\anaconda3\envs\ml\Lib\site-packages\numpy\_core\numeric.py:1467, in normalize_axis_tuple(axis, ndim, argname, allow_duplicate)
#    1465         pass
#    1466 # Going via an iterator directly is slower than via list comprehension.
# -> 1467 axis = tuple(normalize_axis_index(ax, ndim, argname) for ax in axis)
#    1468 if not allow_duplicate and len(set(axis)) != len(axis):
#    1469     if argname:
#
# TypeError: 'float' object is not iterable

# %%
#incorrect percentile syntax.
#corrected code
import numpy as np

data = [10, 12, 14, 16, 18, 100]

Q1, Q3 = np.percentile(data, [25,75])
IQR = Q3 - Q1
outliers = [x for x in data if x < (Q1 - 1.5 * IQR) or x > (Q3 + 1.5 * IQR)]

print("Outliers:", outliers)
# Out:
# Outliers: [100]

# %% [markdown]
# ## 4. Standard Deviation Calculation

# %%
import numpy as np

data = [10, 20, 30, 40, 50]

std_dev = np.std(data, unbiased=True)

print("Standard Deviation:", std_dev)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       1 import numpy as np
#       3 data = [10, 20, 30, 40, 50]
# ----> 5 std_dev = np.std(data, unbiased=True)
#       7 print("Standard Deviation:", std_dev)
#
# TypeError: std() got an unexpected keyword argument 'unbiased'

# %%
#Solution:
#unexpected keyword unbiased
#corrected code
import numpy as np

data = [10, 20, 30, 40, 50]

std_dev = np.std(data)

print("Standard Deviation:", std_dev)
# Out:
# Standard Deviation: 14.142135623730951

# %% [markdown]
# ## 5. Hypothesis Testing using T-Test

# %%
from scipy import stats

medication_group = [110, 115, 108, 102, 107]
placebo_group = [120, 125, 130, 122, 128]

t_stat, p_value = stats.ttest_ind(medication_group, placebo_group, axis=1)

print("T-Statistic:", t_stat)
print("P-Value:", p_value)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[13], line 6
#       3 medication_group = [110, 115, 108, 102, 107]
#       4 placebo_group = [120, 125, 130, 122, 128]
# ----> 6 t_stat, p_value = stats.ttest_ind(medication_group, placebo_group, axis=2)
#       8 print("T-Statistic:", t_stat)
#       9 print("P-Value:", p_value)
#
# File ~\anaconda3\envs\ml\Lib\site-packages\scipy\stats\_axis_nan_policy.py:540, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper(***failed resolving arguments***)
#     537     samples = [xp_ravel(sample) for sample in samples]
#     538 else:
#     539     # don't ignore any axes when broadcasting if paired
# --> 540     samples = _broadcast_arrays(samples, axis=axis if not paired else None)
#     541     axis = (axis,) if np.isscalar(axis) else axis
#     542     n_axes = len(axis)
#
# File ~\anaconda3\envs\ml\Lib\site-packages\scipy\stats\_axis_nan_policy.py:55, in _broadcast_arrays(arrays, axis, xp)
#      53 arrays = [xp.asarray(arr) for arr in arrays]
#      54 shapes = [arr.shape for arr in arrays]
# ---> 55 new_shapes = _broadcast_shapes(shapes, axis)
#      56 if axis is None:
#      57     new_shapes = [new_shapes]*len(arrays)
#
# File ~\anaconda3\envs\ml\Lib\site-packages\scipy\stats\_axis_nan_policy.py:95, in _broadcast_shapes(shapes, axis)
#      92 if axis[-1] >= n_dims or axis[0] < 0:
#      93     message = (f"`axis` is out of bounds "
#      94                f"for array of dimension {n_dims}")
# ---> 95     raise AxisError(message)
#      97 if len(np.unique(axis)) != len(axis):
#      98     raise AxisError("`axis` must contain only distinct elements")
#
# AxisError: `axis` is out of bounds for array of dimension 1

# %%
#Solution
#axis=1 is not a valid parameter
from scipy import stats

medication_group = [110, 115, 108, 102, 107]
placebo_group = [120, 125, 130, 122, 128]

t_stat, p_value = stats.ttest_ind(medication_group, placebo_group)

print("T-Statistic:", t_stat)
print("P-Value:", p_value)
# Out:
# T-Statistic: -5.921023912553299
# P-Value: 0.0003532844625064414

# %% [markdown]
# ## 6.Multicollinearity Detection Using VIF

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor

data = pd.DataFrame({
    'Age': [5, 3, 8, 2, 1, 7, 4, 6, 3, 9],
    'Mileage': [50000, 30000, 80000, 20000, 15000, 70000, 40000, 60000, 35000, 90000],
    'EngineSize': [1.2, 1.6, 2.0, 1.0, 1.3, 2.5, 1.8, 2.2, 1.5, 2.8]
})

vif_data = pd.DataFrame()
vif_data['Feature'] = data.columns
vif_data['VIF'] = [variance_inflation_factor(data.values, i) for i in range(data.shape[1], -1)]

print(vif_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 14
#      12 vif_data = pd.DataFrame()
#      13 vif_data['Feature'] = data.columns
# ---> 14 vif_data['VIF'] = [variance_inflation_factor(data.values, i) for i in range(data.shape[1], -1)]
#      16 print(vif_data)
#
# File ~\anaconda3\envs\ml\Lib\site-packages\pandas\core\frame.py:4672, in DataFrame.__setitem__(self, key, value)
#    4669     self._setitem_array([key], value)
#    4670 else:
#    4671     # set column
# -> 4672     self._set_item(key, value)
#
# File ~\anaconda3\envs\ml\Lib\site-packages\pandas\core\frame.py:4872, in DataFrame._set_item(self, key, value)
#    4862 def _set_item(self, key, value) -> None:
#    4863     """
#    4864     Add series to DataFrame in specified column.
#    4865
#    (...)   4870     ensure homogeneity.
#    4871     """
# -> 4872     value, refs = self._sanitize_column(value)
#    4874     if (
#    4875         key in self.columns
#    4876         and value.ndim == 1
#    4877         and not isinstance(value.dtype, ExtensionDtype)
#    4878     ):
#    4879         # broadcast across multiple columns if necessary
#    4880         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\anaconda3\envs\ml\Lib\site-packages\pandas\core\frame.py:5742, in DataFrame._sanitize_column(self, value)
#    5739     return _reindex_for_setitem(value, self.index)
#    5741 if is_list_like(value):
# -> 5742     com.require_length_match(value, self.index)
#    5743 return sanitize_array(value, self.index, copy=True, allow_2d=True), None
#
# File ~\anaconda3\envs\ml\Lib\site-packages\pandas\core\common.py:601, in require_length_match(data, index)
#     597 """
#     598 Check the length of data matches the length of the index.
#     599 """
#     600 if len(data) != len(index):
# --> 601     raise ValueError(
#     602         "Length of values "
#     603         f"({len(data)}) "
#     604         "does not match length of index "
#     605         f"({len(index)})"
#     606     )
#
# ValueError: Length of values (0) does not match length of index (3)

# %%
#solution:
#Valid column indices are 0, 1, 2
#But range(data.shape[1], -1) produces 3, 2, 1, 0, so 3 causes an error
#Corrected code
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor

data = pd.DataFrame({
    'Age': [5, 3, 8, 2, 1, 7, 4, 6, 3, 9],
    'Mileage': [50000, 30000, 80000, 20000, 15000, 70000, 40000, 60000, 35000, 90000],
    'EngineSize': [1.2, 1.6, 2.0, 1.0, 1.3, 2.5, 1.8, 2.2, 1.5, 2.8]
})

vif_data = pd.DataFrame()
vif_data['Feature'] = data.columns
vif_data['VIF'] = [variance_inflation_factor(data.values, i) for i in range(data.shape[1])]

print(vif_data)
# Out:
#       Feature          VIF
# 0         Age   885.531249
# 1     Mileage  1059.299089
# 2  EngineSize    22.929372
