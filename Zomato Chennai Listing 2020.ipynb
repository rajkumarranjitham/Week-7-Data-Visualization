# %%
#1. Importing the libraries
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as pt
import plotly.express as ex
import plotly.io as pio
pio.renderers.default='svg'

# %%
#2. Importing the dataset
dataset=pd.read_csv("Zomato Chennai Listing 2020.csv")

# %%
dataset.head
# Out:
# <bound method NDFrame.head of                                               Zomato URL  \
# 0      https://www.zomato.com/chennai/yaa-mohaideen-b...
# 1      https://www.zomato.com/chennai/sukkubhai-biriy...
# 2      https://www.zomato.com/chennai/ss-hyderabad-bi...
# 3            https://www.zomato.com/chennai/kfc-perambur
# 4      https://www.zomato.com/chennai/tasty-kitchen-p...
# ...                                                  ...
# 12027  https://www.zomato.com/chennai/cks-sandwiches-...
# 12028  https://www.zomato.com/chennai/cks-sandwiches-...
# 12029  https://www.zomato.com/chennai/cks-sandwiches-...
# 12030  https://www.zomato.com/chennai/cks-sandwiches-...
# 12031  https://www.zomato.com/chennai/cks-sandwiches-...
#
#           Name of Restaurant  \
# 0      Yaa Mohaideen Briyani
# 1         Sukkubhai Biriyani
# 2       SS Hyderabad Biryani
# 3                        KFC
# 4              Tasty Kitchen
# ...                      ...
# 12027        CK's Sandwiches
# 12028        CK's Sandwiches
# 12029        CK's Sandwiches
# 12030        CK's Sandwiches
# 12031        CK's Sandwiches
#
#                                                  Address         Location  \
# 0              336 & 338, Main Road, Pallavaram, Chennai       Pallavaram
# 1       New 14, Old 11/3Q, Railway Station Road, MKN ...          Alandur
# 2       98/339, Arcot Road, Opposite Gokulam Chit Fun...      Kodambakkam
# 3       10, Periyar Nagar, 70 Feet Road, Near Sheeba ...         Perambur
# 4       135B, SRP Colony, Peravallur, Near Perambur, ...         Perambur
# ...                                                  ...              ...
# 12027                                      Delivery Only            Porur
# 12028                                      Delivery Only         Kolathur
# 12029                                      Delivery Only  Anna Nagar East
# 12030                                      Delivery Only        Ramapuram
# 12031                                      Delivery Only   Sholinganallur
#
#                                                  Cuisine  \
# 0                                            ['Biryani']
# 1      ['Biryani', ' North Indian', ' Mughlai', ' Des...
# 2      ['Biryani', ' North Indian', ' Chinese', ' Ara...
# 3      ['Burger', ' Fast Food', ' Finger Food', ' Bev...
# 4      ['Chinese', ' Biryani', ' North Indian', ' Che...
# ...                                                  ...
# 12027                                       ['Sandwich']
# 12028                                       ['Sandwich']
# 12029                                       ['Sandwich']
# 12030                                       ['Sandwich']
# 12031                                       ['Sandwich']
#
#                                               Top Dishes  Price for 2  \
# 0      ['Bread Halwa', ' Chicken 65', ' Mutton Biryan...        500.0
# 1      ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...       1000.0
# 2      ['Brinjal Curry', ' Tandoori Chicken', ' Chick...        500.0
# 3                                      ['Zinger Burger']        500.0
# 4      ['Mutton Biryani', ' Chicken Rice', ' Tomato R...        450.0
# ...                                                  ...          ...
# 12027                                            Invalid        350.0
# 12028                                            Invalid        350.0
# 12029                                            Invalid        350.0
# 12030                                            Invalid        350.0
# 12031                                            Invalid        350.0
#
#        Dining Rating Dining Rating Count  Delivery Rating  \
# 0                4.3                1500              4.3
# 1                4.4                3059              4.1
# 2                4.3                1361              4.4
# 3                4.0                1101              4.0
# 4                4.2                 617              4.1
# ...              ...                 ...              ...
# 12027            NaN                 NaN              NaN
# 12028            NaN                 NaN              NaN
# 12029            NaN                 NaN              NaN
# 12030            NaN                 NaN              NaN
# 12031            NaN                 NaN              NaN
#
#       Delivery Rating Count                                           Features
# 0                      9306                ['Home Delivery', 'Indoor Seating']
# 1                     39200  ['Home Delivery', 'Free Parking', 'Table booki...
# 2                     10500                ['Home Delivery', 'Indoor Seating']
# 3                     11200  ['Home Delivery', 'Free Parking', 'Card Upon D...
# 4                     22400                ['Home Delivery', 'Indoor Seating']
# ...                     ...                                                ...
# 12027                   NaN                     ['Breakfast', 'Delivery Only']
# 12028                   NaN                     ['Breakfast', 'Delivery Only']
# 12029                   NaN                     ['Breakfast', 'Delivery Only']
# 12030                   NaN                     ['Breakfast', 'Delivery Only']
# 12031                   NaN                     ['Breakfast', 'Delivery Only']
#
# [12032 rows x 12 columns]>

# %%
#3. Getting Basic Information about the Dataset
dataset.shape
# Out:
# (12032, 12)

# %%
dataset.info
# Out:
# <bound method DataFrame.info of                                               Zomato URL  \
# 0      https://www.zomato.com/chennai/yaa-mohaideen-b...
# 1      https://www.zomato.com/chennai/sukkubhai-biriy...
# 2      https://www.zomato.com/chennai/ss-hyderabad-bi...
# 3            https://www.zomato.com/chennai/kfc-perambur
# 4      https://www.zomato.com/chennai/tasty-kitchen-p...
# ...                                                  ...
# 12027  https://www.zomato.com/chennai/cks-sandwiches-...
# 12028  https://www.zomato.com/chennai/cks-sandwiches-...
# 12029  https://www.zomato.com/chennai/cks-sandwiches-...
# 12030  https://www.zomato.com/chennai/cks-sandwiches-...
# 12031  https://www.zomato.com/chennai/cks-sandwiches-...
#
#           Name of Restaurant  \
# 0      Yaa Mohaideen Briyani
# 1         Sukkubhai Biriyani
# 2       SS Hyderabad Biryani
# 3                        KFC
# 4              Tasty Kitchen
# ...                      ...
# 12027        CK's Sandwiches
# 12028        CK's Sandwiches
# 12029        CK's Sandwiches
# 12030        CK's Sandwiches
# 12031        CK's Sandwiches
#
#                                                  Address         Location  \
# 0              336 & 338, Main Road, Pallavaram, Chennai       Pallavaram
# 1       New 14, Old 11/3Q, Railway Station Road, MKN ...          Alandur
# 2       98/339, Arcot Road, Opposite Gokulam Chit Fun...      Kodambakkam
# 3       10, Periyar Nagar, 70 Feet Road, Near Sheeba ...         Perambur
# 4       135B, SRP Colony, Peravallur, Near Perambur, ...         Perambur
# ...                                                  ...              ...
# 12027                                      Delivery Only            Porur
# 12028                                      Delivery Only         Kolathur
# 12029                                      Delivery Only  Anna Nagar East
# 12030                                      Delivery Only        Ramapuram
# 12031                                      Delivery Only   Sholinganallur
#
#                                                  Cuisine  \
# 0                                            ['Biryani']
# 1      ['Biryani', ' North Indian', ' Mughlai', ' Des...
# 2      ['Biryani', ' North Indian', ' Chinese', ' Ara...
# 3      ['Burger', ' Fast Food', ' Finger Food', ' Bev...
# 4      ['Chinese', ' Biryani', ' North Indian', ' Che...
# ...                                                  ...
# 12027                                       ['Sandwich']
# 12028                                       ['Sandwich']
# 12029                                       ['Sandwich']
# 12030                                       ['Sandwich']
# 12031                                       ['Sandwich']
#
#                                               Top Dishes  Price for 2  \
# 0      ['Bread Halwa', ' Chicken 65', ' Mutton Biryan...        500.0
# 1      ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...       1000.0
# 2      ['Brinjal Curry', ' Tandoori Chicken', ' Chick...        500.0
# 3                                      ['Zinger Burger']        500.0
# 4      ['Mutton Biryani', ' Chicken Rice', ' Tomato R...        450.0
# ...                                                  ...          ...
# 12027                                            Invalid        350.0
# 12028                                            Invalid        350.0
# 12029                                            Invalid        350.0
# 12030                                            Invalid        350.0
# 12031                                            Invalid        350.0
#
#        Dining Rating Dining Rating Count  Delivery Rating  \
# 0                4.3                1500              4.3
# 1                4.4                3059              4.1
# 2                4.3                1361              4.4
# 3                4.0                1101              4.0
# 4                4.2                 617              4.1
# ...              ...                 ...              ...
# 12027            NaN                 NaN              NaN
# 12028            NaN                 NaN              NaN
# 12029            NaN                 NaN              NaN
# 12030            NaN                 NaN              NaN
# 12031            NaN                 NaN              NaN
#
#       Delivery Rating Count                                           Features
# 0                      9306                ['Home Delivery', 'Indoor Seating']
# 1                     39200  ['Home Delivery', 'Free Parking', 'Table booki...
# 2                     10500                ['Home Delivery', 'Indoor Seating']
# 3                     11200  ['Home Delivery', 'Free Parking', 'Card Upon D...
# 4                     22400                ['Home Delivery', 'Indoor Seating']
# ...                     ...                                                ...
# 12027                   NaN                     ['Breakfast', 'Delivery Only']
# 12028                   NaN                     ['Breakfast', 'Delivery Only']
# 12029                   NaN                     ['Breakfast', 'Delivery Only']
# 12030                   NaN                     ['Breakfast', 'Delivery Only']
# 12031                   NaN                     ['Breakfast', 'Delivery Only']
#
# [12032 rows x 12 columns]>

# %%
dataset.describe
# Out:
# <bound method NDFrame.describe of                                               Zomato URL  \
# 0      https://www.zomato.com/chennai/yaa-mohaideen-b...
# 1      https://www.zomato.com/chennai/sukkubhai-biriy...
# 2      https://www.zomato.com/chennai/ss-hyderabad-bi...
# 3            https://www.zomato.com/chennai/kfc-perambur
# 4      https://www.zomato.com/chennai/tasty-kitchen-p...
# ...                                                  ...
# 12027  https://www.zomato.com/chennai/cks-sandwiches-...
# 12028  https://www.zomato.com/chennai/cks-sandwiches-...
# 12029  https://www.zomato.com/chennai/cks-sandwiches-...
# 12030  https://www.zomato.com/chennai/cks-sandwiches-...
# 12031  https://www.zomato.com/chennai/cks-sandwiches-...
#
#           Name of Restaurant  \
# 0      Yaa Mohaideen Briyani
# 1         Sukkubhai Biriyani
# 2       SS Hyderabad Biryani
# 3                        KFC
# 4              Tasty Kitchen
# ...                      ...
# 12027        CK's Sandwiches
# 12028        CK's Sandwiches
# 12029        CK's Sandwiches
# 12030        CK's Sandwiches
# 12031        CK's Sandwiches
#
#                                                  Address         Location  \
# 0              336 & 338, Main Road, Pallavaram, Chennai       Pallavaram
# 1       New 14, Old 11/3Q, Railway Station Road, MKN ...          Alandur
# 2       98/339, Arcot Road, Opposite Gokulam Chit Fun...      Kodambakkam
# 3       10, Periyar Nagar, 70 Feet Road, Near Sheeba ...         Perambur
# 4       135B, SRP Colony, Peravallur, Near Perambur, ...         Perambur
# ...                                                  ...              ...
# 12027                                      Delivery Only            Porur
# 12028                                      Delivery Only         Kolathur
# 12029                                      Delivery Only  Anna Nagar East
# 12030                                      Delivery Only        Ramapuram
# 12031                                      Delivery Only   Sholinganallur
#
#                                                  Cuisine  \
# 0                                            ['Biryani']
# 1      ['Biryani', ' North Indian', ' Mughlai', ' Des...
# 2      ['Biryani', ' North Indian', ' Chinese', ' Ara...
# 3      ['Burger', ' Fast Food', ' Finger Food', ' Bev...
# 4      ['Chinese', ' Biryani', ' North Indian', ' Che...
# ...                                                  ...
# 12027                                       ['Sandwich']
# 12028                                       ['Sandwich']
# 12029                                       ['Sandwich']
# 12030                                       ['Sandwich']
# 12031                                       ['Sandwich']
#
#                                               Top Dishes  Price for 2  \
# 0      ['Bread Halwa', ' Chicken 65', ' Mutton Biryan...        500.0
# 1      ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...       1000.0
# 2      ['Brinjal Curry', ' Tandoori Chicken', ' Chick...        500.0
# 3                                      ['Zinger Burger']        500.0
# 4      ['Mutton Biryani', ' Chicken Rice', ' Tomato R...        450.0
# ...                                                  ...          ...
# 12027                                            Invalid        350.0
# 12028                                            Invalid        350.0
# 12029                                            Invalid        350.0
# 12030                                            Invalid        350.0
# 12031                                            Invalid        350.0
#
#        Dining Rating Dining Rating Count  Delivery Rating  \
# 0                4.3                1500              4.3
# 1                4.4                3059              4.1
# 2                4.3                1361              4.4
# 3                4.0                1101              4.0
# 4                4.2                 617              4.1
# ...              ...                 ...              ...
# 12027            NaN                 NaN              NaN
# 12028            NaN                 NaN              NaN
# 12029            NaN                 NaN              NaN
# 12030            NaN                 NaN              NaN
# 12031            NaN                 NaN              NaN
#
#       Delivery Rating Count                                           Features
# 0                      9306                ['Home Delivery', 'Indoor Seating']
# 1                     39200  ['Home Delivery', 'Free Parking', 'Table booki...
# 2                     10500                ['Home Delivery', 'Indoor Seating']
# 3                     11200  ['Home Delivery', 'Free Parking', 'Card Upon D...
# 4                     22400                ['Home Delivery', 'Indoor Seating']
# ...                     ...                                                ...
# 12027                   NaN                     ['Breakfast', 'Delivery Only']
# 12028                   NaN                     ['Breakfast', 'Delivery Only']
# 12029                   NaN                     ['Breakfast', 'Delivery Only']
# 12030                   NaN                     ['Breakfast', 'Delivery Only']
# 12031                   NaN                     ['Breakfast', 'Delivery Only']
#
# [12032 rows x 12 columns]>

# %%
dataset.columns
# Out:
# Index(['Zomato URL', 'Name of Restaurant', 'Address', 'Location', 'Cuisine',
#        'Top Dishes', 'Price for 2', 'Dining Rating', 'Dining Rating Count',
#        'Delivery Rating', 'Delivery Rating Count', 'Features'],
#       dtype='str')

# %%
"""
4. Cleaning the Dataset
a. Removing the redundunt rows of data
# Checking redundunt rows of data 

wrong_data=dataset['PAGE NO']=='PAGE NO'
wrong_data
"""
# Out:
# "\n4. Cleaning the Dataset\na. Removing the redundunt rows of data\n# Checking redundunt rows of data \n\nwrong_data=dataset['PAGE NO']=='PAGE NO'\nwrong_data\n"

# %%
# Dropping columns which are not required for further analysis 
dataset.drop(['Zomato URL', 'Address'], axis = 1,inplace=True)

# %%
dataset.head
# Out:
# <bound method NDFrame.head of           Name of Restaurant         Location  \
# 0      Yaa Mohaideen Briyani       Pallavaram
# 1         Sukkubhai Biriyani          Alandur
# 2       SS Hyderabad Biryani      Kodambakkam
# 3                        KFC         Perambur
# 4              Tasty Kitchen         Perambur
# ...                      ...              ...
# 12027        CK's Sandwiches            Porur
# 12028        CK's Sandwiches         Kolathur
# 12029        CK's Sandwiches  Anna Nagar East
# 12030        CK's Sandwiches        Ramapuram
# 12031        CK's Sandwiches   Sholinganallur
#
#                                                  Cuisine  \
# 0                                            ['Biryani']
# 1      ['Biryani', ' North Indian', ' Mughlai', ' Des...
# 2      ['Biryani', ' North Indian', ' Chinese', ' Ara...
# 3      ['Burger', ' Fast Food', ' Finger Food', ' Bev...
# 4      ['Chinese', ' Biryani', ' North Indian', ' Che...
# ...                                                  ...
# 12027                                       ['Sandwich']
# 12028                                       ['Sandwich']
# 12029                                       ['Sandwich']
# 12030                                       ['Sandwich']
# 12031                                       ['Sandwich']
#
#                                               Top Dishes  Price for 2  \
# 0      ['Bread Halwa', ' Chicken 65', ' Mutton Biryan...        500.0
# 1      ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...       1000.0
# 2      ['Brinjal Curry', ' Tandoori Chicken', ' Chick...        500.0
# 3                                      ['Zinger Burger']        500.0
# 4      ['Mutton Biryani', ' Chicken Rice', ' Tomato R...        450.0
# ...                                                  ...          ...
# 12027                                            Invalid        350.0
# 12028                                            Invalid        350.0
# 12029                                            Invalid        350.0
# 12030                                            Invalid        350.0
# 12031                                            Invalid        350.0
#
#        Dining Rating Dining Rating Count  Delivery Rating  \
# 0                4.3                1500              4.3
# 1                4.4                3059              4.1
# 2                4.3                1361              4.4
# 3                4.0                1101              4.0
# 4                4.2                 617              4.1
# ...              ...                 ...              ...
# 12027            NaN                 NaN              NaN
# 12028            NaN                 NaN              NaN
# 12029            NaN                 NaN              NaN
# 12030            NaN                 NaN              NaN
# 12031            NaN                 NaN              NaN
#
#       Delivery Rating Count                                           Features
# 0                      9306                ['Home Delivery', 'Indoor Seating']
# 1                     39200  ['Home Delivery', 'Free Parking', 'Table booki...
# 2                     10500                ['Home Delivery', 'Indoor Seating']
# 3                     11200  ['Home Delivery', 'Free Parking', 'Card Upon D...
# 4                     22400                ['Home Delivery', 'Indoor Seating']
# ...                     ...                                                ...
# 12027                   NaN                     ['Breakfast', 'Delivery Only']
# 12028                   NaN                     ['Breakfast', 'Delivery Only']
# 12029                   NaN                     ['Breakfast', 'Delivery Only']
# 12030                   NaN                     ['Breakfast', 'Delivery Only']
# 12031                   NaN                     ['Breakfast', 'Delivery Only']
#
# [12032 rows x 10 columns]>

# %%
"""
b. Removing the Null Records
 # Checking for Null records
"""
dataset.isnull().sum()
# Out:
# Name of Restaurant          0
# Location                    0
# Cuisine                     0
# Top Dishes                  0
# Price for 2                 0
# Dining Rating            5351
# Dining Rating Count       220
# Delivery Rating          5851
# Delivery Rating Count     220
# Features                    0
# dtype: int64

# %%
# Checking for a null row 
#dataset[dataset['Price for 2'].isnull()]

# %%
# Droping the above row from the dataset 
#dataset=dataset.drop(labels=15080, axis =0)
#dataset

# %%
 # Replacing the other null records with zero
#dataset.fillna(dataset['Dining Rating','Dining Rating Count','Delivery Rating','Delivery Rating Count'].mean(),inplace=True)

# %%
 # Confirming all the null records are correct 
#dataset.isnull().sum()

# %%
"""c. Converting the DataTypes of numerical columns to numeric dataype
# Checking for text values in the column before converting it to numeric datatype 
"""
dataset['Dining Rating'].value_counts()
# Out:
# Dining Rating
# 3.6    584
# 3.5    553
# 3.7    525
# 3.4    500
# 3.3    463
# 3.8    460
# 3.2    433
# 3.9    379
# 3.1    363
# 2.0    354
# 3.0    302
# 4.0    288
# 2.9    257
# 4.1    221
# 2.8    192
# 4.2    142
# 2.7    138
# 4.3    105
# 2.6     99
# 2.5     71
# 4.4     61
# 2.4     46
# 4.5     36
# 2.3     32
# 2.2     20
# 4.6     17
# 4.7     12
# 2.1     10
# 4.9      7
# 4.8      4
# 1.9      3
# 1.7      2
# 0.3      1
# 1.0      1
# Name: count, dtype: int64

# %%
dataset['Dining Rating']
# Out:
# 0        4.3
# 1        4.4
# 2        4.3
# 3        4.0
# 4        4.2
#         ...
# 12027    NaN
# 12028    NaN
# 12029    NaN
# 12030    NaN
# 12031    NaN
# Name: Dining Rating, Length: 12032, dtype: float64

# %%
dataset['Dining Rating'].unique()
# Out:
# array([4.3, 4.4, 4. , 4.2, 4.1, 0. , 3.9, 4.5, 4.7, 3.5, 4.6, 3.6, 3.8,
#        4.9, 4.8, 3.7, 2.7, 2.9, 2.6, 3. , 3.4, 2.4, 3.3, 2.8, 2.1, 2. ,
#        2.2, 3.2, 2.5, 3.1, 2.3, 1.9, 1.7, 0.3, 1. ])

# %%
dataset=dataset.dropna(subset=['Dining Rating'])

# %%
 # Replacing the text values with '0' 
dataset['Dining Rating']=dataset['Dining Rating'].fillna(0)

# %%
 # Checking for text values in the column before converting it to numeric datatype 
dataset['Dining Rating Count'].value_counts()
# Out:
# Dining Rating Count
# 4      339
# 5      271
# 6      248
# 8      180
# 9      168
#       ...
# 858      1
# 477      1
# 388      1
# 253      1
# 224      1
# Name: count, Length: 791, dtype: int64

# %%
dataset['Dining Rating Count'].unique()
# Out:
# <StringArray>
# ['1500', '3059', '1361', '1101',  '617',  '567',  '668', '2564', '1578',
#   '743',
#  ...
#   '318',  '683',  '431',  '359',  '858',  '477',  '388',  '273',  '253',
#   '224']
# Length: 791, dtype: str

# %%
 # Replacing the text values with '0'
dataset['Dining Rating Count']=dataset['Dining Rating Count'].replace(to_replace=['Does not offer Dining','Not enough Dining Reviews'], value=0, inplace=True)
# Out:
# C:\Users\Diwali 6\AppData\Local\Temp\ipykernel_14832\2475943634.py:2: ChainedAssignmentError:
#
# A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html

# %%
dataset['Dining Rating Count']=dataset['Dining Rating Count'].fillna(0)
dataset['Dining Rating Count'].unique()
# Out:
# <StringArray>
# ['1500', '3059', '1361', '1101',  '617',  '567',  '668', '2564', '1578',
#   '743',
#  ...
#   '318',  '683',  '431',  '359',  '858',  '477',  '388',  '273',  '253',
#   '224']
# Length: 791, dtype: str

# %%
dataset['Delivery Rating'].value_counts()
# Out:
# Delivery Rating
# 3.9    939
# 3.8    530
# 4.0    437
# 3.7    411
# 4.1    356
# 3.6    330
# 4.2    304
# 3.5    220
# 4.3    219
# 3.4    169
# 3.3    118
# 4.4     98
# 3.2     61
# 3.1     44
# 4.5     43
# 3.0     31
# 2.9     17
# 4.6     16
# 2.8      8
# 2.6      6
# 2.7      5
# 1.8      5
# 2.4      3
# 4.7      3
# 2.2      3
# 2.1      2
# 2.3      1
# 1.6      1
# 1.5      1
# Name: count, dtype: int64

# %%
dataset['Delivery Rating'].unique()
# Out:
# array([4.3, 4.1, 4.4, 4. , 3.8, 4.2, 3.9, 3.6, nan, 3.3, 3.4, 3.7, 3.5,
#        4.5, 2.9, 4.6, 3.1, 2.7, 3.2, 3. , 2.8, 2.4, 2.3, 4.7, 2.6, 2.1,
#        1.8, 2.2, 1.6, 1.5])

# %%
dataset['Delivery Rating']=dataset['Delivery Rating'].replace(to_replace=['nan'], value='0', inplace=True)
# Out:
# C:\Users\Diwali 6\AppData\Local\Temp\ipykernel_14832\408172563.py:1: ChainedAssignmentError:
#
# A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html

# %%
dataset['Delivery Rating']=dataset['Delivery Rating'].fillna(0)

dataset['Delivery Rating'].unique()
# Out:
# array([4.3, 4.1, 4.4, 4. , 3.8, 4.2, 3.9, 3.6, 0. , 3.3, 3.4, 3.7, 3.5,
#        4.5, 2.9, 4.6, 3.1, 2.7, 3.2, 3. , 2.8, 2.4, 2.3, 4.7, 2.6, 2.1,
#        1.8, 2.2, 1.6, 1.5])

# %%
dataset['Delivery Rating Count']=dataset['Delivery Rating Count'].replace(to_replace=['Does not offer Delivery','Not enough Delivery Reviews'], value='0', inplace=True)
dataset['Delivery Rating Count']=dataset['Delivery Rating Count'].fillna(0)
dataset['Delivery Rating Count'].unique()
# Out:
# C:\Users\Diwali 6\AppData\Local\Temp\ipykernel_14832\236257833.py:1: ChainedAssignmentError:
#
# A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
# <StringArray>
# [ '9306', '39200', '10500', '11200', '22400', '24700',  '4320', '21700',
#  '39600',  '6226',
#  ...
#   '1474',  '4493',  '7093',   '896',    '10',     '9',  '1004',  '1976',
#    '221',  '1617']
# Length: 2030, dtype: str

# %%
dataset.columns
# Out:
# Index(['Name of Restaurant', 'Location', 'Cuisine', 'Top Dishes',
#        'Price for 2', 'Dining Rating', 'Dining Rating Count',
#        'Delivery Rating', 'Delivery Rating Count', 'Features'],
#       dtype='str')

# %%
dataset['Price for 2'].unique()
# Out:
# array([ 500., 1000.,  450.,  800., 1400.,  700.,  350.,  900.,  300.,
#        1200., 2000.,  400.,  650., 1500.,  250.,  550.,  600.,  750.,
#         200., 1800., 1100., 1600., 2500.,  100., 2700., 1700., 1300.,
#         150., 1650.,  850., 2400., 3400., 1350., 3500., 2800., 4500.,
#        4000., 3100., 3000., 2600., 1850., 1900., 3300., 2200., 2100.,
#        4800., 5000., 3800., 3200., 1550., 2300.,  950.,   60., 1150.,
#         160.,   40.,  120.,  330.,  140.])

# %%
# Changing Data Type of the numerical columns 

dataset['Price for 2'] = dataset['Price for 2'].astype('int64') 
dataset['Dining Rating'] = dataset['Dining Rating'].astype('float64') 
dataset['Dining Rating Count'] = dataset['Dining Rating Count'].astype('float64') 
dataset['Delivery Rating'] = dataset['Delivery Rating'].astype('float64') 
dataset['Delivery Rating Count'] = dataset['Delivery Rating Count'].astype('float64')

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 6681 entries, 0 to 11802
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name of Restaurant     6681 non-null   str
#  1   Location               6681 non-null   str
#  2   Cuisine                6681 non-null   str
#  3   Top Dishes             6681 non-null   str
#  4   Price for 2            6681 non-null   int64
#  5   Dining Rating          6681 non-null   float64
#  6   Dining Rating Count    6681 non-null   float64
#  7   Delivery Rating        6681 non-null   float64
#  8   Delivery Rating Count  6681 non-null   float64
#  9   Features               6681 non-null   str
# dtypes: float64(4), int64(1), str(5)
# memory usage: 574.1 KB

# %%
dataset.isnull().sum()
# Out:
# Name of Restaurant       0
# Location                 0
# Cuisine                  0
# Top Dishes               0
# Price for 2              0
# Dining Rating            0
# Dining Rating Count      0
# Delivery Rating          0
# Delivery Rating Count    0
# Features                 0
# dtype: int64

# %%
#dataset.drop(columns=['Delivery Rating Countg'], inplace=True)

# %%
#d. Working with 'Timing' column
#dataset['TIMING'].value_counts()

# %%
 # Splitting the column and storing it in temp_df dataframe  
#temp_df = dataset['TIMING'].str.split("(", n = 1, expand = True) 
#temp_df

# %%
 # Assigning the columns back to the raw_df dataframe 
#dataset['TIMING'] = temp_df[0] 
#dataset['DAYS_OPEN'] = temp_df[1] 
#dataset.head()

# %%
# Removing the bracket character from Days column 
 
#dataset['DAYS_OPEN'] = dataset['DAYS_OPEN'].str.replace("\)","",regex=True) 
#dataset.head()

# %%
#dataset.isnull().sum()

# %%
#dataset.fillna('NA', inplace=True)

# %%
#dataset.info()

# %%
 # Finding those restaurant whose has 0 Rating or Votes 
 
#useless_data = (dataset['RATING'] == 0.0) | (dataset['VOTES'] == 0) 
#dataset[useless_data]

# %%
#dataset = dataset[~useless_data]

# %%
# Checking the unique values in the column 
 
#dataset['RATING_TYPE'].value_counts()

# %%
 # Translating the texts into proper English text 
""" 
dataset['RATING_TYPE']=dataset['RATING_TYPE'].replace(to_replace='Excelente' , value='Excellent', inplace=True) 
dataset['RATING_TYPE']=dataset['RATING_TYPE'].replace(to_replace=['Veľmi dobré','Bardzo dobrze','Muy Bueno','Velmi dobré'] , value='Very Good', inplace=True)
dataset['RATING_TYPE']=dataset['RATING_TYPE'].replace(to_replace=['Skvělá volba','Dobrze','Bueno','Buono','Dobré','Bom','Skvělé'] , value='Good', inplace=True)
dataset['RATING_TYPE']=dataset['RATING_TYPE'].replace(to_replace=['Priemer','Média','Çok iyi'] , value='Average', inplace=True) 
dataset['RATING_TYPE']=dataset['RATING_TYPE'].replace(to_replace=['Průměr','Promedio','Ortalama','Muito Bom','İyi'] , value='Poor', inplace=True)
dataset['RATING_TYPE']=dataset['RATING_TYPE'].replace(to_replace=['Baik','Biasa','Media','Sangat Baik'] , value='Very Poor', inplace=True) 
"""
# Out:
# " \ndataset['RATING_TYPE']=dataset['RATING_TYPE'].replace(to_replace='Excelente' , value='Excellent', inplace=True) \ndataset['RATING_TYPE']=dataset['RATING_TYPE'].replace(to_replace=['Veľmi dobré','Bardzo dobrze','Muy Bueno','Velmi dobré'] , value='Very Good', inplace=True)\ndataset['RATING_TYPE']=dataset['RATING_TYPE'].replace(to_replace=['Skvělá volba','Dobrze','Bueno','Buono','Dobré','Bom','Skvělé'] , value='Good', inplace=True)\ndataset['RATING_TYPE']=dataset['RATING_TYPE'].replace(to_replace=['Priemer','Média','Çok iyi'] , value='Average', inplace=True) \ndataset['RATING_TYPE']=dataset['RATING_TYPE'].replace(to_replace=['Průměr','Promedio','Ortalama','Muito Bom','İyi'] , value='Poor', inplace=True)\ndataset['RATING_TYPE']=dataset['RATING_TYPE'].replace(to_replace=['Baik','Biasa','Media','Sangat Baik'] , value='Very Poor', inplace=True) \n"

# %%
# Checking all the values correctly mapped 
 
#dataset['RATING_TYPE'].value_counts()

# %%
#dataset['REGION'].value_counts()

# %%
 # Removing the irrelevant text from the Region column
 
#dataset['REGION'] = dataset['REGION'].str.replace('[a-zA-Z].+-- ','',regex=True)

# %%
# Removing the West & East from the Region column 
 
#dataset['REGION'] = dataset['REGION'].str.replace(' West| west| East| east','',regex=True)

# %%
#dataset['REGION'].value_counts()

# %%
dataset['Location'] = dataset['Location'].str.replace('\\(','',regex=True) 
dataset['Location'] = dataset['Location'].str.replace('\\)','',regex=True) 

dataset['Location'].unique()
# Out:
# <StringArray>
# [                                            'Pallavaram',
#                                                 'Alandur',
#                                             'Kodambakkam',
#                                                'Perambur',
#                                              'Medavakkam',
#                                         'Anna Nagar East',
#                                                'T. Nagar',
#                                               'Velachery',
#                                              'Vadapalani',
#                                                   'Porur',
#  ...
#                                            'Meenambakkam',
#                             'Hotel Joyland, Chengalpattu',
#                 'Spectrum The Grand Venus Mall, Perambur',
#                       'Hotel Goutham Manor, Nungambakkam',
#                         'Hotel Anitha Towers, Triplicane',
#                                   'Vivira Mall, Navallur',
#                                  'DLF IT Park, Ramapuram',
#  'RMZ Millenia Business Park, Old Mahabalipuram Road OMR',
#                                 'RK Salai Cathedral Road',
#                       'Chandra Metro Mall, Virugambakkam']
# Length: 264, dtype: str

# %%
dataset['Location'] = dataset['Location'].str.replace('Chandra Metro Mall, Virugambakkam','Virugambakkam',regex=True) 
dataset['Location'] = dataset['Location'].str.replace('RMZ Millenia Business Park, Old Mahabalipuram Road OMR','Old Mahabalipuram Road OM',regex=True) 
dataset['Location'] = dataset['Location'].str.replace( 'DLF IT Park, Ramapuram','Ramapuram',regex=True) 
dataset['Location'] = dataset['Location'].str.replace( 'Vivira Mall, Navallur','Navallur',regex=True) 
dataset['Location'] = dataset['Location'].str.replace( 'Hotel NRS Sakithyan, T. Nagar','T. Nagar',regex=True) 
dataset['Location'] = dataset['Location'].str.replace( 'Hotel Peninsula, T. Nagar','T. Nagar',regex=True) 
dataset['Location'] = dataset['Location'].str.replace( 'Hotel Sathyam Grand Resort, Kanchipuram District','Kanchipuram District',regex=True) 
dataset['Location'] = dataset['Location'].str.replace( 'Hotel Anitha Towers, Triplicane','Triplicane',regex=True) 
dataset['Location'] = dataset['Location'].str.replace( 'Hotel Goutham Manor, Nungambakkam','Nungambakkam',regex=True)

# %%
dataset['Cuisine'] = dataset['Cuisine'].str.replace('\\[','',regex=True) 
dataset['Cuisine'] = dataset['Cuisine'].str.replace('\\]','',regex=True) 
dataset['Cuisine'].unique()
# Out:
# <StringArray>
# [                                                                           ''Biryani'',
#                     ''Biryani', ' North Indian', ' Mughlai', ' Desserts', ' Beverages'',
#                                    ''Biryani', ' North Indian', ' Chinese', ' Arabian'',
#                                  ''Burger', ' Fast Food', ' Finger Food', ' Beverages'',
#                      ''Chinese', ' Biryani', ' North Indian', ' Chettinad', ' Arabian'',
#                                           ''South Indian', ' North Indian', ' Chinese'',
#                                                                  ''Cafe', ' Fast Food'',
#                         ''Arabian', ' Chinese', ' North Indian', ' Lebanese', ' Salad'',
#  ''South Indian', ' North Indian', ' Chinese', ' Chettinad', ' Desserts', ' Beverages'',
#                                                                ''Burger', ' Fast Food'',
#  ...
#                                               ''Fast Food', ' South Indian', ' Mithai'',
#                                                  ''American', ' Mexican', ' Fast Food'',
#                                ''Biryani', ' North Indian', ' Chettinad', ' Beverages'',
#                              ''Beverages', ' North Indian', ' Fast Food', ' Ice Cream'',
#                                                            ''Street Food', ' Sandwich'',
#                                                        ''Coffee', ' Tea', ' Beverages'',
#                                                ''Bakery', ' Beverages', ' Street Food'',
#                                                              ''Hyderabadi', ' Biryani'',
#                                  ''Chettinad', ' Chinese', ' North Indian', ' Biryani'',
#                                     ''Juices', ' Beverages', ' Sandwich', ' Fast Food'']
# Length: 1853, dtype: str

# %%
# Replacing Small regions with Known region name 
"""
dataset['REGION'] = dataset['REGION'].str.replace('4 Bungalows|7 Andheri|Azad Nagar|Near Andheri Station|Veera Desai Area','Sion',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('Bandra Kurla Complex','Bandra',regex=True) 
dataset['REGION'] = dataset['REGION'].str.replace('CBD-Belapur','CBD Belapur',regex=True) 
dataset['REGION'] = dataset['REGION'].str.replace('Girgaon Chowpatty','Chowpatty',regex=True) 
dataset['REGION'] = dataset['REGION'].str.replace('Dadar Shivaji Park','Dadar',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('Flea Bazaar Café|Kamala Mills Compound','Lower Parel',regex=True) 
dataset['REGION'] = dataset['REGION'].str.replace('Runwal Green','Mulund',regex=True) 
dataset['REGION'] = dataset['REGION'].str.replace('Mumbai CST Area','Mumbai Central',regex=True) 
dataset['REGION'] = dataset['REGION'].str.replace('Kopar Khairane|Seawoods|Turbhe|Ulwe','Navi Mumbai',regex=True) 
dataset['REGION'] = dataset['REGION'].str.replace('New Panvel|Old Panvel','Panvel',regex=True) 
dataset['REGION'] = dataset['REGION'].str.replace('Kamothe','Sion',regex=True) 
dataset['REGION'] = dataset['REGION'].str.replace('Ghodbunder Road|Majiwada','Thane',regex=True)
"""
# Out:
# "\ndataset['REGION'] = dataset['REGION'].str.replace('4 Bungalows|7 Andheri|Azad Nagar|Near Andheri Station|Veera Desai Area','Sion',regex=True)\ndataset['REGION'] = dataset['REGION'].str.replace('Bandra Kurla Complex','Bandra',regex=True) \ndataset['REGION'] = dataset['REGION'].str.replace('CBD-Belapur','CBD Belapur',regex=True) \ndataset['REGION'] = dataset['REGION'].str.replace('Girgaon Chowpatty','Chowpatty',regex=True) \ndataset['REGION'] = dataset['REGION'].str.replace('Dadar Shivaji Park','Dadar',regex=True)\ndataset['REGION'] = dataset['REGION'].str.replace('Flea Bazaar Café|Kamala Mills Compound','Lower Parel',regex=True) \ndataset['REGION'] = dataset['REGION'].str.replace('Runwal Green','Mulund',regex=True) \ndataset['REGION'] = dataset['REGION'].str.replace('Mumbai CST Area','Mumbai Central',regex=True) \ndataset['REGION'] = dataset['REGION'].str.replace('Kopar Khairane|Seawoods|Turbhe|Ulwe','Navi Mumbai',regex=True) \ndataset['REGION'] = dataset['REGION'].str.replace('New Panvel|Old Panvel','Panvel',regex=True) \ndataset['REGION'] = dataset['REGION'].str.replace('Kamothe','Sion',regex=True) \ndataset['REGION'] = dataset['REGION'].str.replace('Ghodbunder Road|Majiwada','Thane',regex=True)\n"

# %%
dataset[dataset.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Name of Restaurant, Location, Cuisine, Top Dishes, Price for 2, Dining Rating, Dining Rating Count, Delivery Rating, Delivery Rating Count, Features]
# Index: []

# %%
# Dropping all the duplicate rows 
 
dataset = dataset.drop_duplicates()

# %%
#4. Copying the cleaned data into a new DataFrame
zomato_df = dataset.copy() 
zomato_df.head()
# Out:
#       Name of Restaurant     Location  \
# 0  Yaa Mohaideen Briyani   Pallavaram
# 1     Sukkubhai Biriyani      Alandur
# 2   SS Hyderabad Biryani  Kodambakkam
# 3                    KFC     Perambur
# 4          Tasty Kitchen     Perambur
#
#                                              Cuisine  \
# 0                                          'Biryani'
# 1  'Biryani', ' North Indian', ' Mughlai', ' Dess...
# 2  'Biryani', ' North Indian', ' Chinese', ' Arab...
# 3  'Burger', ' Fast Food', ' Finger Food', ' Beve...
# 4  'Chinese', ' Biryani', ' North Indian', ' Chet...
#
#                                           Top Dishes  Price for 2  \
# 0  ['Bread Halwa', ' Chicken 65', ' Mutton Biryan...          500
# 1  ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...         1000
# 2  ['Brinjal Curry', ' Tandoori Chicken', ' Chick...          500
# 3                                  ['Zinger Burger']          500
# 4  ['Mutton Biryani', ' Chicken Rice', ' Tomato R...          450
#
#    Dining Rating  Dining Rating Count  Delivery Rating  Delivery Rating Count  \
# 0            4.3               1500.0              4.3                 9306.0
# 1            4.4               3059.0              4.1                39200.0
# 2            4.3               1361.0              4.4                10500.0
# 3            4.0               1101.0              4.0                11200.0
# 4            4.2                617.0              4.1                22400.0
#
#                                             Features
# 0                ['Home Delivery', 'Indoor Seating']
# 1  ['Home Delivery', 'Free Parking', 'Table booki...
# 2                ['Home Delivery', 'Indoor Seating']
# 3  ['Home Delivery', 'Free Parking', 'Card Upon D...
# 4                ['Home Delivery', 'Indoor Seating']

# %%
#!pip install --upgrade kaleido

# %%
zomato_df.columns
# Out:
# Index(['Name of Restaurant', 'Location', 'Cuisine', 'Top Dishes',
#        'Price for 2', 'Dining Rating', 'Dining Rating Count',
#        'Delivery Rating', 'Delivery Rating Count', 'Features'],
#       dtype='str')

# %%
#5. Performing Exploratory Data Analysis
#Q1) How many restaurants are in Mumbai for each type of cuisine?
"""
import kaleido
fig = ex.histogram(zomato_df, x='Name of Restaurant', color='Name of Restaurant',  
             title= 'No. of Restaurants by Cuisine Type',  
             labels={'Name of Restaurant':'Name of Restaurant'}) 
 
fig.show() 
"""
# Out:
# "\nimport kaleido\nfig = ex.histogram(zomato_df, x='Name of Restaurant', color='Name of Restaurant',  \n             title= 'No. of Restaurants by Cuisine Type',  \n             labels={'Name of Restaurant':'Name of Restaurant'}) \n\nfig.show() \n"

# %%
#Q2) What are the percentage of restaurants by Rating Type in Chennai?
rating_type_df = zomato_df['Dining Rating'].value_counts().reset_index() 
rating_type_df.rename(columns={'index':'Dining Rating', 'Dining Rating':'Dining Rating'}, inplace=True) 
rating_type_df
# Out:
#     Dining Rating  count
# 0             3.6    584
# 1             3.5    553
# 2             3.7    525
# 3             3.4    500
# 4             3.3    463
# 5             3.8    460
# 6             3.2    433
# 7             3.9    379
# 8             3.1    363
# 9             2.0    354
# 10            3.0    302
# 11            4.0    288
# 12            2.9    257
# 13            4.1    221
# 14            2.8    192
# 15            4.2    142
# 16            2.7    138
# 17            4.3    105
# 18            2.6     99
# 19            2.5     71
# 20            4.4     61
# 21            2.4     46
# 22            4.5     36
# 23            2.3     32
# 24            2.2     20
# 25            4.6     17
# 26            4.7     12
# 27            2.1     10
# 28            4.9      7
# 29            4.8      4
# 30            1.9      3
# 31            1.7      2
# 32            0.3      1
# 33            1.0      1

# %%
fig = ex.pie(rating_type_df, names='Dining Rating', values='count', color='Dining Rating',  
title='Percentage of Restaurants by Rating Type').update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %%
#Q3) Which are the Top 10 highest rated Seafood Restaurant in Chennai?

seafood_df = zomato_df[zomato_df['Cuisine'].str.contains('Seafood')] 
seafood_df.sort_values(by='Dining Rating',ascending=False).head(10)
# Out:
#                                Name of Restaurant  \
# 195                                    The Marina
# 214             Sera - The Tapas Bar & Restaurant
# 292                          Alchemy Bar & Lounge
# 96                                  Urban Spatula
# 315                                       Layalee
# 342                                 L'attitude 49
# 282  Bay View - Taj Fisherman's Cove Resort & Spa
# 358       The Wharf 2.0 - Radisson BLU  Templebay
# 133                                    Azzuri Bay
# 64                                          Samco
#
#                                               Location  \
# 195                                       Nungambakkam
# 214                                        Gopalapuram
# 292                            Hotel Rajpark, Alwarpet
# 96                                     Anna Nagar West
# 315                                      Ekkaduthangal
# 342                                  Grande Bay Resort
# 282  Taj Fisherman's Cove Resort & Spa, Kanchipuram...
# 358              Radisson Blu Temple Bay, Mamallapuram
# 133                                              Adyar
# 64                                           Velachery
#
#                                                Cuisine  \
# 195             'Seafood', ' North Indian', ' Chinese'
# 214  'Finger Food', ' Seafood', ' Italian', ' Conti...
# 292  'Continental', ' Finger Food', ' Seafood', ' F...
# 96   'Continental', ' Seafood', ' Biryani', ' Itali...
# 315  'Arabian', ' BBQ', ' Seafood', ' Chinese', ' C...
# 342  'Singaporean', ' Thai', ' Asian', ' Chinese', ...
# 282   'Seafood', ' South Indian', ' Andhra', ' Kerala'
# 358  'Seafood', ' Mediterranean', ' Italian', ' Nor...
# 133  'Italian', ' Mediterranean', ' Thai', ' Seafoo...
# 64   'Arabian', ' Chinese', ' North Indian', ' Seaf...
#
#                                             Top Dishes  Price for 2  \
# 195  ['Sea Food', ' Jumbo Prawns', ' Biryani', ' Fi...         1600
# 214  ['Cocktails', ' Pasta', ' Nachos', ' Mashed Po...         1600
# 292  ['Cocktails', ' Fries', ' Brownie', ' Peri Per...         2000
# 96   ['Burgers', ' Pasta', ' Fish', ' Fries', ' Chi...          800
# 315  ['Fish', ' Faluda', ' Shawarma', ' Brownie', '...          700
# 342  ['Sea Food', ' Fish', ' Pasta', ' Noodle', ' B...         1800
# 282  ['Sea Food', ' Fish Curry', ' Chips', ' Cockta...         3500
# 358  ['Sea Food', ' Jumbo Prawns', ' Pasta', ' Fish...         3000
# 133  ['Pasta', ' Pizza', ' Sea Food', ' Tiramisu', ...         1000
# 64   ['Biryani', ' Bbq Chicken', ' Faluda', ' Peppe...          800
#
#      Dining Rating  Dining Rating Count  Delivery Rating  \
# 195            4.8               1082.0              4.3
# 214            4.5                964.0              3.4
# 292            4.5                432.0              0.0
# 96             4.4                794.0              4.3
# 315            4.4                586.0              4.1
# 342            4.4                563.0              0.0
# 282            4.4                678.0              0.0
# 358            4.4                517.0              0.0
# 133            4.3               2430.0              4.0
# 64             4.3               1078.0              3.7
#
#      Delivery Rating Count                                           Features
# 195                  373.0  ['Home Delivery', 'Indoor Seating', 'Table res...
# 214                   50.0  ['Home Delivery', 'Full Bar Available', 'Free ...
# 292                    0.0  ['Full Bar Available', 'Live Sports Screening'...
# 96                   911.0  ['Home Delivery', 'Free Parking', 'Table booki...
# 315                  143.0  ['Home Delivery', 'Table booking recommended',...
# 342                    0.0  ['Breakfast', 'Wheelchair Accessible', 'Full B...
# 282                    0.0  ['Wheelchair Accessible', 'Full Bar Available'...
# 358                    0.0  ['Wheelchair Accessible', 'Full Bar Available'...
# 133                  369.0  ['Home Delivery', 'Rooftop', 'Table reservatio...
# 64                  3862.0  ['Home Delivery', 'Valet Parking Available', '...

# %%
#Q5) Which places have the highest rated restaurant for each Cuisine Type in chennai?
# Assuming restaurants having rating above 4.5 
 
highest_rated_df = zomato_df[zomato_df['Dining Rating'] >= 4.5] 
highest_rated_df
# Out:
#               Name of Restaurant         Location  \
# 15                 Welcome Hotel     Purasavakkam
# 24                Eating Circles         Alwarpet
# 37                  Shree Mithai          Chetpet
# 50                   Andhikkadai        Velachery
# 57                Brownie Heaven       Royapettah
# ...                          ...              ...
# 9279  Gastronomer By Double Roti        Teynampet
# 9358               Writer's Cafe         Taramani
# 9363                 Flower Drum            Adyar
# 9367                 Cream Stone     Thuraipakkam
# 9541                Bombay Kulfi  Anna Nagar East
#
#                                         Cuisine  \
# 15    'South Indian', ' Desserts', ' Beverages'
# 24                               'South Indian'
# 37       'Mithai', ' Street Food', ' Fast Food'
# 50                               'South Indian'
# 57          'Bakery', ' Desserts', ' Beverages'
# ...                                         ...
# 9279          'Cafe', ' American', ' Fast Food'
# 9358                        'Cafe', ' American'
# 9363                         'Chinese', ' Thai'
# 9367                   'Desserts', ' Ice Cream'
# 9541                                'Ice Cream'
#
#                                              Top Dishes  Price for 2  \
# 15    ['Pongal', ' Podi Dosa', ' Idli Sambar', ' Vad...          300
# 24    ['Rose Milk', ' Neer Dosa', ' Thatte Idli', ' ...          250
# 37    ['Chaat', ' Badam Milk', ' Pav Bhaji', ' Panip...          300
# 50    ['Coffee', ' Sweet Kozhukattai', ' Idli', ' Po...          200
# 57    ['Vanilla Ice Cream', ' Brownie Shake', ' Filt...          350
# ...                                                 ...          ...
# 9279  ['Burgers', ' Fries', ' Oreo Shake', ' Healthy...          900
# 9358  ['Hot Chocolate', ' Pizza', ' Pasta', ' Waffle...          600
# 9363  ['Momos', ' Noodle', ' Dimsum Platter', ' Sche...          800
# 9367  ['Death By Chocolate', ' Chocolava', ' Tiramis...          350
# 9541  ['Calcutta Paan', ' Tender Coconut Kulfi', ' P...          200
#
#       Dining Rating  Dining Rating Count  Delivery Rating  \
# 15              4.5               1094.0              0.0
# 24              4.7                782.0              4.2
# 37              4.6               1085.0              4.4
# 50              4.6                908.0              4.2
# 57              4.9                842.0              4.3
# ...             ...                  ...              ...
# 9279            4.5               2341.0              4.2
# 9358            4.5                497.0              4.1
# 9363            4.5                617.0              4.3
# 9367            4.5                683.0              4.2
# 9541            4.6                397.0              4.4
#
#       Delivery Rating Count                                           Features
# 15                      0.0  ['Breakfast', 'Vegetarian Only', 'Indoor Seati...
# 24                   2744.0  ['Breakfast', 'Home Delivery', 'Vegetarian Onl...
# 37                  18600.0  ['Breakfast', 'Home Delivery', 'Vegetarian Onl...
# 50                  17300.0  ['Breakfast', 'Home Delivery', 'Vegetarian Onl...
# 57                   2270.0  ['Home Delivery', 'Indoor Seating', 'Desserts ...
# ...                     ...                                                ...
# 9279                 2577.0        ['Home Delivery', 'Indoor Seating', 'Wifi']
# 9358                  360.0  ['Home Delivery', 'Indoor Seating', 'Table boo...
# 9363                  819.0  ['Home Delivery', 'Wheelchair Accessible', 'Ve...
# 9367                 4553.0  ['Home Delivery', 'Vegetarian Only', 'Indoor S...
# 9541                 3468.0  ['Home Delivery', 'Sugar Free Options', 'Free ...
#
# [76 rows x 10 columns]

# %%
#Q7) Which areas have a large number of Chinese Restaurant Market?
chinese_df = zomato_df[zomato_df['Cuisine'].str.contains('Chinese')] 
chinese_df
# Out:
#                                Name of Restaurant         Location  \
# 2                            SS Hyderabad Biryani      Kodambakkam
# 4                                   Tasty Kitchen         Perambur
# 5                                      Dine N Fun       Medavakkam
# 8                               Savoury Sea Shell  Anna Nagar East
# 9                        Sangeetha Veg Restaurant         T. Nagar
# ...                                           ...              ...
# 11545                          Anandhi Idly Kadai         Selaiyur
# 11641  Hotel New Arcot Biriyani & Catering Center         GST Road
# 11642                  Valasai New Arcot Biriyani        Ramapuram
# 11736          Adyar Vaishnavas Thattu Idly Kadai            Porur
# 11785                           Engineers Kitchen         Ambattur
#
#                                                  Cuisine  \
# 2      'Biryani', ' North Indian', ' Chinese', ' Arab...
# 4      'Chinese', ' Biryani', ' North Indian', ' Chet...
# 5            'South Indian', ' North Indian', ' Chinese'
# 8      'Arabian', ' Chinese', ' North Indian', ' Leba...
# 9      'South Indian', ' North Indian', ' Chinese', '...
# ...                                                  ...
# 11545                         'South Indian', ' Chinese'
# 11641  'Chettinad', ' Chinese', ' North Indian', ' Bi...
# 11642                 'Biryani', ' Chinese', ' Lebanese'
# 11736  'South Indian', ' Sandwich', ' Chinese', ' Str...
# 11785              'North Indian', ' Chinese', ' Andhra'
#
#                                               Top Dishes  Price for 2  \
# 2      ['Brinjal Curry', ' Tandoori Chicken', ' Chick...          500
# 4      ['Mutton Biryani', ' Chicken Rice', ' Tomato R...          450
# 5      ['Chicken Grill', ' Shawarma', ' Naan', ' Chic...          450
# 8      ['Shawarma', ' Chicken Grill', ' Brownie', ' S...         1400
# 9      ['Filtered Coffee', ' Chaat', ' Faluda', ' Mas...          800
# ...                                                  ...          ...
# 11545                                            Invalid          200
# 11641                                            Invalid          300
# 11642                                            Invalid          400
# 11736                                            Invalid          200
# 11785                                            Invalid          400
#
#        Dining Rating  Dining Rating Count  Delivery Rating  \
# 2                4.3               1361.0              4.4
# 4                4.2                617.0              4.1
# 5                4.1                567.0              3.8
# 8                4.2               2564.0              4.1
# 9                4.4               1578.0              4.2
# ...              ...                  ...              ...
# 11545            3.1                 17.0              4.1
# 11641            3.7                 11.0              0.0
# 11642            3.3                  8.0              0.0
# 11736            3.2                  6.0              3.9
# 11785            2.5                  6.0              3.5
#
#        Delivery Rating Count  \
# 2                    10500.0
# 4                    22400.0
# 5                    24700.0
# 8                    21700.0
# 9                    39600.0
# ...                      ...
# 11545                  367.0
# 11641                    0.0
# 11642                    0.0
# 11736                   48.0
# 11785                  214.0
#
#                                                 Features
# 2                    ['Home Delivery', 'Indoor Seating']
# 4                    ['Home Delivery', 'Indoor Seating']
# 5                    ['Home Delivery', 'Indoor Seating']
# 8      ['Home Delivery', 'Indoor Seating', 'Card Upon...
# 9      ['Breakfast', 'Home Delivery', 'Vegetarian Onl...
# ...                                                  ...
# 11545   ['Breakfast', 'Home Delivery', 'Indoor Seating']
# 11641                ['Home Delivery', 'Indoor Seating']
# 11642                                 ['Indoor Seating']
# 11736                ['Home Delivery', 'Indoor Seating']
# 11785                ['Home Delivery', 'Indoor Seating']
#
# [2360 rows x 10 columns]

# %%
chinese_rest_df = chinese_df.groupby(by='Location').agg({'Name of Restaurant' : 'count', 'Price for 2' : 'mean'}).rename(columns= {'Name of Restaurant' : 'COUNT OF RESTAURANTS'})
chinese_rest_df = chinese_rest_df.sort_values('COUNT OF RESTAURANTS', ascending=False).head(25)
chinese_rest_df.head()
# Out:
#                  COUNT OF RESTAURANTS  Price for 2
# Location
# Porur                              81   459.876543
# T. Nagar                           71   516.901408
# Ambattur                           68   402.941176
# Anna Nagar East                    66   613.636364
# Perambur                           66   446.212121

# %%
chinese_rest_df.columns
# Out:
# Index(['COUNT OF RESTAURANTS', 'Price for 2'], dtype='str')

# %%
chinese_rest_df=chinese_rest_df.reset_index()

# %%
print(chinese_rest_df.columns)
# Out:
# Index(['Location', 'COUNT OF RESTAURANTS', 'Price for 2'], dtype='str')

# %%
fig = ex.bar(chinese_rest_df, x='Location', y='COUNT OF RESTAURANTS', color='Price for 2', title= 'No. of Chinese Restaurant by places') 
fig.show()

# %%
#Q8) Is there a relation between Price and Rating by each Cuisine Type?
price_rating_df = zomato_df.groupby(['Cuisine', 'Dining Rating'])['Price for 2'].mean().reset_index() 
price_rating_df
# Out:
#                                                 Cuisine  Dining Rating  \
# 0     'American', ' Andhra', ' Asian', ' Beverages',...            2.4
# 1                            'American', ' Continental'            4.1
# 2     'American', ' Continental', ' European', ' Ita...            3.9
# 3     'American', ' Continental', ' Italian', ' Nort...            4.1
# 4                              'American', ' Fast Food'            2.7
# ...                                                 ...            ...
# 4010                                'Tibetan', ' Momos'            3.5
# 4011                                'Tibetan', ' Momos'            3.6
# 4012                                'Tibetan', ' Momos'            3.8
# 4013                                'Tibetan', ' Momos'            4.0
# 4014                                'Turkish', ' Kebab'            4.3
#
#       Price for 2
# 0           800.0
# 1          1600.0
# 2           700.0
# 3           800.0
# 4           300.0
# ...           ...
# 4010        400.0
# 4011        400.0
# 4012        400.0
# 4013        400.0
# 4014        500.0
#
# [4015 rows x 3 columns]

# %%
fig = ex.line(price_rating_df, y="Price for 2", x="Dining Rating",color='Cuisine')
fig.show()

# %%
#Q9) Is there a relation between Region and Price?
region_price_df = zomato_df.groupby(['Location'])['Price for 2'].mean().reset_index() 
region_price_df

# %%
fig = ex.scatter(region_price_df, x="Location", y="Price for 2").update_traces(marker_size=8) 
fig.show()

# %%
#Q10) Find the list of Affordable Restaurants?
"""
The criteria for Affordable Restaurants would be:
1) Low Price 2) High Rated
First step will be to find the restaurants with average cost 1/4th the average cost of most expensive restaurant in our dataframe.
Let me explain:-The most expensive restaurant has an average meal cost= 6000. We'll try to stay economical and only pick the
restaurants that are 1/4th of 6000
"""

# %%
zomato_df.columns

# %%
max_price = zomato_df['Price for 2'].max() 
one_fourth_price = max_price/4 
one_fourth_price

# %%
# Finding list of restaurants that have price less than and equal to 1/4th of the max price i.e Finding Cheap Restauran
 
aff_rest_df = zomato_df[['Name of Restaurant', 'Price for 2', 'Cuisine', 'Location']] 
aff_rest_df = aff_rest_df[aff_rest_df['Price for 2'] <= 1250] 
aff_rest_df.sort_values(by='Price for 2', inplace=True) 
aff_rest_df

# %%
 # Finding the highest rated list of restaurants 
 
highrate_rest_df = zomato_df[['Name of Restaurant', 'Price for 2', 'Cuisine', 'Location','Dining Rating']] 
highrate_rest_df = highrate_rest_df[highrate_rest_df['Dining Rating'] >= 4.5] 
highrate_rest_df.sort_values(by='Price for 2', inplace=True) 
highrate_rest_df

# %%
"""
Now, we'll merge the aff_rest_df with highrate_rest_df to obtain the intersection i.e the list of Affordable Restaurants !!
"""
highrate_aff_df = pd.merge(aff_rest_df, highrate_rest_df, how='inner', on=['Name of Restaurant', 'Location']) 
highrate_aff_df = highrate_aff_df[['Name of Restaurant', 'Price for 2_x', 'Cuisine_x', 'Location']] 
highrate_aff_df.rename(columns={'NAME':'NAME', 'Price for 2_x':'Price for 2', 'Cuisine_x':'Cuisine',  
                                'Location':'Location'},inplace=True)

# %%
 # Affordable Restaurants with low price and high rating  
 
highrate_aff_df

# %%
reliable_rest_df
